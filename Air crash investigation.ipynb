# %% [markdown]
# # Air crash investigation
#
# In this project, a data set of airplane accident statistics to analyze patterns and look for any common threads.The data set that contains 77,282 aviation accidents that occurred in the U.S., and the metadata associated with them.

# %%
import pandas as pd
import numpy as np


dataset = pd.read_csv('AviationData.txt', delimiter = '|')

# %%
dataset.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20150908X74637             Accident        CEN15LA402    09/08/2015
# 1  20150906X32704             Accident        ERA15LA339    09/05/2015
# 2  20150908X00229             Accident        GAA15CA251    09/04/2015
# 3  20150903X33216             Accident        WPR15FA256    09/03/2015
# 4  20150903X34535             Accident        ERA15LA338    09/03/2015
#
#          Location          Country     Latitude      Longitude   \
# 0    Freeport, IL    United States    42.246111     -89.581945
# 1     Laconia, NH    United States    43.606389     -71.452778
# 2       Hayes, SD    United States
# 3      Santee, CA    United States    32.829445    -116.988611
# 4   Cresskill, NJ    United States    40.935833     -73.958611
#
#    Airport Code                 Airport Name   ...  Air Carrier   \
# 0          KFEP             albertus Airport   ...
# 1           LCI    Laconia Municipal Airport   ...
# ...

# %%
### Read as list
# Search through aviation_list for LAX94LA336

import csv
f = open('AviationData.txt')
aviation_data=f.readlines()
aviation_list=[]
for line in aviation_data:
    aviation_list.append(line.split("|"))
lax_code=[]
for line in aviation_list:
    if 'LAX94LA336' in line:
        lax_code.append(line)
print(lax_code)
# Out:
# []
